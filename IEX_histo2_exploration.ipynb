# %%
from beamline_29 import IEX

# %%
import time
import matplotlib.pyplot as plt
import math

# %%
# %matplotlib widget

# %%
import numpy as np

# %%
data = IEX.run()

# %%
data
# Out:
# 68412

# %%
data = IEX.run(nbins = 64)

# %%
data
# Out:
# {'error': 1,
#  'col_h': 1,
#  'col_v': 2,
#  'nolost': 0,
#  'nbins_h': 64,
#  'nbins_v': 64,
#  'ref': 23,
#  'xrange': [-0.0631498439792448, 0.07066960089230243],
#  'yrange': [-6.762332881160571e-13, 6.028307410546607e-13],
#  'bin_h_edges': array([-0.06314984, -0.06105892, -0.05896799, -0.05687706, -0.05478613,
#         -0.0526952 , -0.05060427, -0.04851334, -0.04642241, -0.04433148,
#         -0.04224056, -0.04014963, -0.0380587 , -0.03596777, -0.03387684,
#         -0.03178591, -0.02969498, -0.02760405, -0.02551313, -0.0234222 ,
#         -0.02133127, -0.01924034, -0.01714941, -0.01505848, -0.01296755,
#         -0.01087662, -0.00878569, -0.00669477, -0.00460384, -0.00251291,
#         -0.00042198,  0.00166895,  0.00375988,  0.00585081,  0.00794174,
#          0.01003266,  0.01212359,  0.01421452,  0.01630545,  0.01839638,
#          0.02048731,  0.02257824,  0.02466917,  0.0267601 ,  0.02885102,
#          0.03094195,  0.03303288,  0.03512381,  0.03721474,  0.03930567,
# ...

# %%
data['histogram'].shape
# Out:
# (64, 64)

# %%
fig, ax = plt.subplots(1,1)
ax = plt.imshow(data['histogram'], cmap='viridis', interpolation='nearest')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig1, ax1 = plt.subplots(1,1)

h, w = data['histogram'].shape

ax1 =  plt.imshow(data['histogram'], cmap='hot', interpolation='nearest')
plt.xticks(ticks = np.arange(w), labels = (data['bin_h_center']*1000).astype(int))
plt.yticks(ticks = np.arange(h), labels = (data['bin_v_center']*1e14).astype(int))

plt.colorbar()

plt.show()
